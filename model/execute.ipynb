# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import os
os.chdir('drive/My Drive/bigcontest2019/fbip team/model')

# %%
# !python survival_time.py

# %%
# !python total_amount_spent.py
